# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# ### First load the data and make some data cleaning and convert the lables into numerical values

# %%
df = pd.read_table("final/processed_squamous_done.txt", sep=" ")
df = df.replace({"Normal": 0, "tumor": 1})
df
# Out:
#      ABCA4  ABCB4  ABCC2  ACSL6  ACTL8  ADAMTS18  ADAMTS6  ADAMTS8  \
# 0      177     89    101    122      1        26      674     8241
# 1      187     38     69     66      0       220       46     2092
# 2      326    688    118    292      1        16      233     1189
# 3       56      9     36     39      0         7      109     4978
# 4      125     44     58     85      1         5      206     8034
# 5       90     52     76     81      0         6      249     2245
# 6       98     25     62     54      0         3       84     3356
# 7       57     29     79     53      0        20      109     3283
# 8      107     16     48     33      0         1       78     2407
# 9      316     39     29     58      0         9       53     5510
# 10     170     35    101     74      0        37      121     5380
# 11     132     16     62     63      0         0       74      984
# 12      92     41     38     87      0        24       71     2523
# 13     271     53     43    132      0        74      103     3484
# 14     149     40     60     98      0       106      130     1469
# 15      51     22     40     66      0         5       71     1737
# 16     153     74     37    133      0        14       76     1422
# 17      75    111     35     96      0         7      170     3269
# 18     124     30     72    151      1         5       57     4945
# 19      79     30     64     83      0        36      176     1863
# 20     139     29     32     94      0       127       89     6547
# 21     294     32     48    171      1        18      143     1612
# 22      68     32     19    183      0         4       65     4029
# 23     264     62     52    119      0         8      173    10575
# 24      43     15     38     88      0         3       67     2684
# 25     224     33     25    115      0         6       58     4011
# 26      78     41     40    113      0        11       88     7513
# 27     258     73     30    105      1        23      102     2985
# 28      87     27     62     82      0         8      175     4783
# 29     344     72     59    144      0        16       86     7111
# ..     ...    ...    ...    ...    ...       ...      ...      ...
# 521     99     14    206    101    222        10       84       84
# 522    472     29     33      0    132         0        9       14
# 523    526     11    535     52    145        15       26       43
# 524   1628     22     65    135     11        28       74      135
# 525    208      6     37     62     11        58        9       10
# 526    100     43    377     11      2        51       86       33
# 527     96     39     43     11      1        26       53       31
# 528    281    108   3989     21     15       156      107      162
# 529    138     37     80     89      0        10      157     5145
# 530      6     10     14     65      5         9       38        6
# 531   4491     27    212    517     59       145       52       95
# 532    169    118     28     33      0       816       71      198
# 533     79     34     50     34      9       362      123       67
# 534    315     38     48     52      0        22       61      121
# 535     53     54    189     36     11         7       65       32
# 536      4      4     23     16     60        44       34       14
# 537     29     33     33     61     20         9       30       88
# 538      9     14     53      6      1         2       13       10
# 539     79     36     27    492      3        14      129       60
# 540     74     34     39    114    112        39      154      221
# 541  21286     35    710     50     37        19       11        7
# 542     14    158   2578     26      4        93       49       15
# 543   3132     22  10303     99     13         5       50       13
# 544   2377     33     60     20     88       114       32       23
# 545     54     54     35      4      5        69      198       40
# 546  26336     10    172     76     33        22       25      123
# 547    957    109     25     70      9        91       57      116
# 548     69     28    100     19      4        24       77       38
# 549    493     62     57     54      2         7       52       34
# 550    251     67     55     86      1        45       62       51
#
#      ADAMTS9-AS1  ADCYAP1R1  ...     WIF1  XKR4  XKRX  ZBTB16  ZC3H12D  \
# 0            919        757  ...    24149    59   398    5548      336
# 1            110        456  ...     5418    52    52     580      222
# 2            106         76  ...     4880   136   183     821     1721
# 3            351        323  ...     8050    14   159    2638       75
# 4            662        148  ...    16317    39   148    9723      174
# 5            220         26  ...     9486    41   184     478       92
# 6            171        158  ...    18224    18   117    1906      113
# 7            150        300  ...     5456     9    71     580      137
# 8            144         97  ...     3188    65   117     829      106
# 9            200        483  ...    16181   112    62    3917       88
# 10           790        314  ...    20015   164    36    3197       94
# 11           115         86  ...     4239     2   241    3470      107
# 12           160        202  ...    10259    16    91      94       93
# 13           259        287  ...     9426    44   173    1985      198
# 14           129        363  ...     6873    26    54     837      149
# 15           434        205  ...     6006    12   169     958       51
# 16           130        112  ...     4149    14    98     323      333
# 17           233        203  ...     2341    32    82     481      207
# 18           297        202  ...     8238    33   118    1096      180
# 19           368        143  ...     3179    23   130     227      175
# 20          2244         84  ...    13629    67    58    1392      186
# 21           206        178  ...     5532    18    97     335      267
# 22           229        347  ...     6421    26   213     137       35
# 23           339        208  ...     7603    71   205    2886      140
# 24           247         73  ...     8639    37   109     686       74
# 25           345        135  ...    13396    66   103     638      121
# 26           276        423  ...     8176    22   423     966       97
# 27           211        193  ...     1677    16    60     398      182
# 28           538        227  ...    27094    42   200    6963      100
# 29           351        311  ...    21914    92   182    2042      116
# ..           ...        ...  ...      ...   ...   ...     ...      ...
# 521           16         22  ...      130    12   326     420      151
# 522            2          7  ...       15     5   264      53       28
# 523            4         50  ...       24     2    56      18       74
# 524            9         18  ...     1360     3   116      48       72
# 525            4         13  ...      124     1    44       1      133
# 526           27         22  ...        1     4   168       8      114
# 527           28         28  ...       76     4   374      47       53
# 528           16         15  ...     2386     8   186     550      236
# 529          190        105  ...     9991     9   139     727      240
# 530            2          8  ...    11784     2   103       7       67
# 531           13         51  ...      113    22    66       9      109
# 532           25         20  ...      106     9   181      56      193
# 533           26         34  ...       19     1   273      13      313
# 534           32          9  ...      320    17   263     433      131
# 535           11         15  ...     4468     5   218     714      157
# 536           11          5  ...        5     0    58       6      440
# 537            7         10  ...      596     4   142      35      140
# 538            5          7  ...      499     0     6      10       55
# 539           34         11  ...    22048     3   115      56       61
# 540           35         76  ...      507     4   222      25      174
# 541           16          1  ...       36     0    61      13       61
# 542           20         10  ...       56     4    11      27       66
# 543            7         28  ...       31     3   112       9       46
# 544            7        275  ...       10     7    28      14      150
# 545            6        290  ...       81    18    95      44       35
# 546           17         45  ...      120     0    80      54       20
# 547           27        165  ...    21923    20   115      42      318
# 548           41         47  ...      116     3   166      11       87
# 549            4        202  ...      162     4   113       2      145
# 550           12         37  ...       15    41    56      66      387
#
#      ZFHX4-AS1  ZFR2  ZNF536  ZNF560  label
# 0            0    49     100      12      0
# 1            0    25      28       3      0
# 2            1    30      13       6      0
# 3            0    14      24       3      0
# 4            0    24     116       3      0
# 5            0    48      21       9      0
# 6            0    25      45       3      0
# 7            0    20      76       6      0
# 8            0    82       9       3      0
# 9            2    16      48      19      0
# 10           0    23      21       2      0
# 11           0    12      15       3      0
# 12           1    12      16       1      0
# 13           0    69      50       1      0
# 14           0    27      10       6      0
# 15           2    11      12       0      0
# 16           0    17       8       1      0
# 17           0    13      74       2      0
# 18           0    34      28       2      0
# 19           0    33      42       6      0
# 20           3    15      22       6      0
# 21           0    27      17       4      0
# 22           0    23      41       1      0
# 23           3    41      89       2      0
# 24           1     7      31       1      0
# 25           4     9      16       2      0
# 26           1    21      52       2      0
# 27           0     9      29       1      0
# 28           0    31      42       5      0
# 29           2    27      92       3      0
# ..         ...   ...     ...     ...    ...
# 521          2    67      49       1      1
# 522          8     0       0       0      1
# 523          2     2       0       2      1
# 524         77    21       0       1      1
# 525        186    15     103       0      1
# 526         12     2       0       3      1
# 527          0     4       2       3      1
# 528        289    26       2       6      1
# 529          0    69      46       0      1
# 530          0     1       0       0      1
# 531         17    42     923       0      1
# 532        102     2       5       0      1
# 533          2     7       3       3      1
# 534          0     9       1       0      1
# 535          0     3     234       0      1
# 536        226     4       2       1      1
# 537          0     1       0       1      1
# 538          0     1       0       0      1
# 539          4     4      14       2      1
# 540          8    43      18       0      1
# 541          0    14       0       0      1
# 542          3     1       0       1      1
# 543          0    83       4       0      1
# 544         16    90       1       0      1
# 545          0     5     157       2      1
# 546          0   100       3       0      1
# 547        171    23     896       0      1
# 548          0     3       0       1      1
# 549          4    74       7      88      1
# 550          0    13       1       1      1
#
# [551 rows x 455 columns]

# %% [markdown]
# ### Dividing the data into attributes and labels

# %%
y = df.label
X = df.drop('label', axis=1)

# %% [markdown]
# ### Dividing the data into training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %% [markdown]
# ### Since the data has a wide variance of values so scaling the data will be much more powerful for prediction

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Training the data using random forest classifier which has the number of estimator that defines the number of trees

# %%
regressor = RandomForestClassifier(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %% [markdown]
# ### calculate the accuracy of the model using cofusion matrix and accuracy score

# %%
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[ 21   0]
#  [  1 199]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        21
#            1       1.00      0.99      1.00       200
#
#     accuracy                           1.00       221
#    macro avg       0.98      1.00      0.99       221
# weighted avg       1.00      1.00      1.00       221
#
# 0.995475113122172

# %% [markdown]
# ### trying with different estimator

# %%
regressor = RandomForestClassifier(n_estimators=5, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[ 20   1]
#  [  0 200]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        21
#            1       1.00      1.00      1.00       200
#
#     accuracy                           1.00       221
#    macro avg       1.00      0.98      0.99       221
# weighted avg       1.00      1.00      1.00       221
#
# 0.995475113122172

# %% [markdown]
# ### trying with different estimator

# %%
regressor = RandomForestClassifier(n_estimators=10, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[ 21   0]
#  [  1 199]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        21
#            1       1.00      0.99      1.00       200
#
#     accuracy                           1.00       221
#    macro avg       0.98      1.00      0.99       221
# weighted avg       1.00      1.00      1.00       221
#
# 0.995475113122172

# %% [markdown]
# #### so changing the number of estimators didn't change the results

# %%
regressor.n_outputs_
# Out:
# 1
